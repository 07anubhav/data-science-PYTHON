# %% [markdown]
# ## Pulling Data from public APIs - GET request

# %% [markdown]
# https://exchangeratesapi.io/documentation/

# %%
url = 'http://api.exchangeratesapi.io/v1/latest'
access_key = '?access_key=be7fbb798b129b575459462dd7a10ae4'

base_url = url + access_key

# %% [markdown]
# ## Extracting data on currency exchange rates
# ### Sending a GET request

# %%
import requests

# %% [markdown]
# * The **'.get()'** method submits the GET request to the indicated URL and returns the response from the server

# %%
response = requests.get(base_url)

# %% [markdown]
# ### Investigating the Response

# %%
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"success":true,"timestamp":1687708503,"base":"EUR","date":"2023-06-25","rates":{"AED":4.014963,"AFN":93.254188,"ALL":107.488721,"AMD":420.038693,"ANG":1.957948,"AOA":868.4963,"ARS":275.463714,"AUD":1.636913,"AWG":1.967634,"AZN":1.862661,"BAM":1.955049,"BBD":2.193558,"BDT":117.524867,"BGN":1.962392,"BHD":0.410442,"BIF":3070.120983,"BMD":1.09313,"BND":1.469636,"BOB":7.507117,"BRL":5.228562,"BSD":1.086383,"BTC":3.5732757e-5,"BTN":89.0564,"BWP":14.592396,"BYN":2.742147,"BYR":21425.352035,"BZD":2.189859,"CAD":1.444408,"CDF":2601.650285,"CHF":0.980155,"CLF":0.031834,"CLP":874.034345,"CNY":7.84857,"COP":4454.18946,"CRC":587.974201,"CUC":1.09313,"CUP":28.96795,"CVE":110.227669,"CZK":23.730877,"DJF":193.425719,"DKK":7.472205,"DOP":59.877005,"DZD":147.767253,"EGP":33.640081,"ERN":16.396953,"ETB":59.247747,"EUR":1,"FJD":2.430302,"FKP":0.85979,"GBP":0.859785,"GEL":2.869511,"GGP":0.85979,"GHS":12.537185,"GIP":0.85979,"GMD":65.04546,"GNF":9340.413007,"GTQ":8.517729,"GYD":229.771761,"HKD":8.55915
# ...

# %%
response.content
# Out:
# b'{"success":true,"timestamp":1687708503,"base":"EUR","date":"2023-06-25","rates":{"AED":4.014963,"AFN":93.254188,"ALL":107.488721,"AMD":420.038693,"ANG":1.957948,"AOA":868.4963,"ARS":275.463714,"AUD":1.636913,"AWG":1.967634,"AZN":1.862661,"BAM":1.955049,"BBD":2.193558,"BDT":117.524867,"BGN":1.962392,"BHD":0.410442,"BIF":3070.120983,"BMD":1.09313,"BND":1.469636,"BOB":7.507117,"BRL":5.228562,"BSD":1.086383,"BTC":3.5732757e-5,"BTN":89.0564,"BWP":14.592396,"BYN":2.742147,"BYR":21425.352035,"BZD":2.189859,"CAD":1.444408,"CDF":2601.650285,"CHF":0.980155,"CLF":0.031834,"CLP":874.034345,"CNY":7.84857,"COP":4454.18946,"CRC":587.974201,"CUC":1.09313,"CUP":28.96795,"CVE":110.227669,"CZK":23.730877,"DJF":193.425719,"DKK":7.472205,"DOP":59.877005,"DZD":147.767253,"EGP":33.640081,"ERN":16.396953,"ETB":59.247747,"EUR":1,"FJD":2.430302,"FKP":0.85979,"GBP":0.859785,"GEL":2.869511,"GGP":0.85979,"GHS":12.537185,"GIP":0.85979,"GMD":65.04546,"GNF":9340.413007,"GTQ":8.517729,"GYD":229.771761,"HKD":8.5591
# ...

# %% [markdown]
# ### Handling the JSON

# %%
response.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
response.json()
# Out:
# {'success': True,
#  'timestamp': 1687708503,
#  'base': 'EUR',
#  'date': '2023-06-25',
#  'rates': {'AED': 4.014963,
#   'AFN': 93.254188,
#   'ALL': 107.488721,
#   'AMD': 420.038693,
#   'ANG': 1.957948,
#   'AOA': 868.4963,
#   'ARS': 275.463714,
#   'AUD': 1.636913,
#   'AWG': 1.967634,
#   'AZN': 1.862661,
#   'BAM': 1.955049,
#   'BBD': 2.193558,
#   'BDT': 117.524867,
#   'BGN': 1.962392,
#   'BHD': 0.410442,
#   'BIF': 3070.120983,
#   'BMD': 1.09313,
#   'BND': 1.469636,
#   'BOB': 7.507117,
#   'BRL': 5.228562,
#   'BSD': 1.086383,
#   'BTC': 3.5732757e-05,
#   'BTN': 89.0564,
#   'BWP': 14.592396,
#   'BYN': 2.742147,
#   'BYR': 21425.352035,
#   'BZD': 2.189859,
#   'CAD': 1.444408,
#   'CDF': 2601.650285,
#   'CHF': 0.980155,
#   'CLF': 0.031834,
#   'CLP': 874.034345,
#   'CNY': 7.84857,
#   'COP': 4454.18946,
#   'CRC': 587.974201,
#   'CUC': 1.09313,
#   'CUP': 28.96795,
#   'CVE': 110.227669,
#   'CZK': 23.730877,
#   'DJF': 193.425719,
#   'DKK': 7.472205,
# ...

# %%
type(response.json())
# Out:
# dict

# %% [markdown]
# ### Python 'json' package
# * **loads(string):** convert a json formatted string to a python object
# * **dumps(obj):** converts a python object back to a regular string, with options to make the string prettier

# %%
import json

# %%
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "success": true,
#     "timestamp": 1687708503,
#     "base": "EUR",
#     "date": "2023-06-25",
#     "rates": {
#         "AED": 4.014963,
#         "AFN": 93.254188,
#         "ALL": 107.488721,
#         "AMD": 420.038693,
#         "ANG": 1.957948,
#         "AOA": 868.4963,
#         "ARS": 275.463714,
#         "AUD": 1.636913,
#         "AWG": 1.967634,
#         "AZN": 1.862661,
#         "BAM": 1.955049,
#         "BBD": 2.193558,
#         "BDT": 117.524867,
#         "BGN": 1.962392,
#         "BHD": 0.410442,
#         "BIF": 3070.120983,
#         "BMD": 1.09313,
#         "BND": 1.469636,
#         "BOB": 7.507117,
#         "BRL": 5.228562,
#         "BSD": 1.086383,
#         "BTC": 3.5732757e-05,
#         "BTN": 89.0564,
#         "BWP": 14.592396,
#         "BYN": 2.742147,
#         "BYR": 21425.352035,
#         "BZD": 2.189859,
#         "CAD": 1.444408,
#         "CDF": 2601.650285,
#         "CHF": 0.980155,
#         "CLF": 0.031834,
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['success', 'timestamp', 'base', 'date', 'rates'])
